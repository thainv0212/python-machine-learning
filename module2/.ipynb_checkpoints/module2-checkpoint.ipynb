# %% [markdown]
# ## Supervised Learning: Datasets

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
plt.figure()
plt.title('Sample regression problem with one input variable')
X_R1, y_R1 = make_regression(n_samples=100, n_features=1,n_informative=1, 
                             bias=150, noise=30, random_state=0)
plt.scatter(X_R1, y_R1, marker='o', s=50)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from sklearn.datasets import make_classification

# %%
plt.figure()
X_R2, y_R2 = make_classification(n_samples=100, n_features=2, n_informative=2,
                                n_redundant=0, n_clusters_per_class=1, flip_y=0.1, class_sep=0.5, random_state=0)
plt.scatter(X_R2[:,0], X_R2[:,1], c=y_R2, marker='o', s=50)
plt.show()
# len(X_R2), len(y_R2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
make_classification?

# %% [markdown]
# ### K-Nearest Neighbors: Classification and Regression

# %% [markdown]
# ### Linear Regression: Ridge, Lasso, and Polynomial Regression

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.datasets import make_classification
scaler = MinMaxScaler()
# Out:
# /mnt/data1/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
plt.figure()
X_R2, y_R2 = make_classification(n_samples=100, n_features=2, n_informative=2,
                                n_redundant=0, n_clusters_per_class=1, flip_y=0.1, class_sep=0.5, random_state=0)
plt.scatter(X_R2[:,0], X_R2[:,1], c=y_R2, marker='o', s=50)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
scaler.fit(X_R2)
X_train_scaled = scaler.transform(X_R2)
plt.figure()
plt.scatter(X_train_scaled[:,0], X_train_scaled[:,1], c=y_R2, marker='o', s=50)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Logistic Regression

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LogisticRegression
from adspy_shared_utilities import plot_class_regions_for_classifier_subplot
from sklearn.model_selection import train_test_split

# %%
df = pd.read_table('fruit_data_with_colors.txt')
df.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
Y_apple = (df['fruit_label'] == 1).astype(int).values
X_data = df[['width', 'height']].values

# %%
fig, subaxes = plt.subplots(1,1, figsize=(7,5))
X_train, X_test, y_train, y_test = train_test_split(X_data, Y_apple, random_state=0)
clf = LogisticRegression(C=1000).fit(X_train, y_train)
plot_class_regions_for_classifier_subplot(clf, X_train, y_train, None,
                                         None, 'Logistic Regression \
                                         for binary classification \nFruit dataset: Apple vs others',
                                         subaxes)
h=6
w=8
print('A fruit with height {} and width {} is predicted to be: {}'.
     format(h, w, ['not an apple', 'an apple'][clf.predict([[h,w]])[0]]))
h=10
w=7
print('A fruit with height {} and width {} is predicted to be: {}'.
     format(h, w, ['not an apple', 'an apple'][clf.predict([[h,w]])[0]]))
subaxes.set_xlabel('height')
subaxes.set_ylabel('width')
print('Accuracy on training set: {}'.format(clf.score(X_train, y_train)))
print('Accuracy on test set: {}'.format(clf.score(X_test, y_test)))
# Out:
# <div id='e7763847-4928-4e92-bdf0-fe4e93816017'></div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-04039b1c3850> in <module>()
#       5                                          'None', 'Logistic Regression \
#       6                                          for binary classification \nFruit dataset: Apple vs others',
# ----> 7                                          subaxes)
#       8 h=6
#       9 w=8
#
# /mnt/data1/project/tutorials/python-machine-learning/module2/adspy_shared_utilities.py in plot_class_regions_for_classifier_subplot(clf, X, y, X_test, y_test, title, subplot, target_names, plot_decision_regions)
#     114
#     115     if (X_test is not None):
# --> 116         subplot.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cmap_bold, s=plot_symbol_size, marker='^', edgecolor = 'black')
#     117         train_score = clf.score(X, y)
#     118         test_score  = clf.score(X_test, y_test)
#
# TypeError: string indices must be integers
