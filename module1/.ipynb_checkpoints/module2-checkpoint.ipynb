# %% [markdown]
# ## Supervised Learning: Datasets

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
plt.figure()
plt.title('Sample regression problem with one input variable')
X_R1, y_R1 = make_regression(n_samples=100, n_features=1,n_informative=1, 
                             bias=150, noise=30, random_state=0)
plt.scatter(X_R1, y_R1, marker='o', s=50)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from sklearn.datasets import make_classification

# %%
X_R2, y_R2 = make_classification(n_samples=100, n_features=2, n_informative=2,
                                n_redundant=0, n_clusters_per_class=1, flip_y=0.1, class_sep=0.5, random_state=0)
plt.scatter(X_R2, y_R2, marker='o', s=50)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-f534628d4a23> in <module>()
#       1 X_R2, y_R2 = make_classification(n_samples=100, n_features=2, n_informative=2,
#       2                                 n_redundant=0, n_clusters_per_class=1, flip_y=0.1, class_sep=0.5, random_state=0)
# ----> 3 plt.scatter(X_R2, y_R2, marker='o', s=50)
#       4 plt.show()
#
# /mnt/data1/anaconda3/envs/coursera/lib/python3.5/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3432                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3433                          linewidths=linewidths, verts=verts,
# -> 3434                          edgecolors=edgecolors, data=data, **kwargs)
#    3435     finally:
#    3436         ax._hold = washold
#
# /mnt/data1/anaconda3/envs/coursera/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /mnt/data1/anaconda3/envs/coursera/lib/python3.5/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3962         y = np.ma.ravel(y)
#    3963         if x.size != y.size:
# -> 3964             raise ValueError("x and y must be the same size")
#    3965
#    3966         if s is None:
#
# ValueError: x and y must be the same size

# %%
make_classification?
